# %%
#Importar librerías necesarias
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import pyarrow as pa
import pyarrow.parquet as pq

# %%
# Leer el archivo línea por línea y cargar cada línea como un objeto JSON
with open('output_steam_games.json', 'r', encoding='utf-8') as archivo:
    data = [json.loads(line) for line in archivo]

# Convertir la lista de objetos JSON en un DataFrame
df_games = pd.DataFrame(data)
print(df_games.shape)
df_games
# Out:
# (120445, 13)
#               publisher                                 genres  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 120440            Colony On Mars            Colony On Mars
# 120441  LOGistICAL: South Africa  LOGistICAL: South Africa
# 120442             Russian Roads             Russian Roads
# 120443       EXIT 2 - Directions       EXIT 2 - Directions
# 120444               Maze Run VR                       NaN
#
#                                                       url release_date  \
# 0                                                     NaN          NaN
# 1                                                     NaN          NaN
# 2                                                     NaN          NaN
# 3                                                     NaN          NaN
# 4                                                     NaN          NaN
# ...                                                   ...          ...
# 120440  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 120441  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 120442  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 120443  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
# 120444  http://store.steampowered.com/app/681550/Maze_...          NaN
#
#                                                      tags  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120440              [Strategy, Indie, Casual, Simulation]
# 120441                          [Strategy, Indie, Casual]
# 120442                        [Indie, Simulation, Racing]
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
# 120444  [Early Access, Adventure, Indie, Action, Simul...
#
#                                               reviews_url  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120440  http://steamcommunity.com/app/773640/reviews/?...
# 120441  http://steamcommunity.com/app/733530/reviews/?...
# 120442  http://steamcommunity.com/app/610660/reviews/?...
# 120443  http://steamcommunity.com/app/658870/reviews/?...
# 120444  http://steamcommunity.com/app/681550/reviews/?...
#
#                                                     specs price early_access  \
# 0                                                     NaN   NaN          NaN
# 1                                                     NaN   NaN          NaN
# 2                                                     NaN   NaN          NaN
# 3                                                     NaN   NaN          NaN
# 4                                                     NaN   NaN          NaN
# ...                                                   ...   ...          ...
# 120440                [Single-player, Steam Achievements]  1.99        False
# 120441  [Single-player, Steam Achievements, Steam Clou...  4.99        False
# 120442  [Single-player, Steam Achievements, Steam Trad...  1.99        False
# 120443   [Single-player, Steam Achievements, Steam Cloud]  4.99        False
# 120444  [Single-player, Stats, Steam Leaderboards, HTC...  4.99         True
#
#             id                 developer
# 0          NaN                       NaN
# 1          NaN                       NaN
# 2          NaN                       NaN
# 3          NaN                       NaN
# 4          NaN                       NaN
# ...        ...                       ...
# 120440  773640        Nikita "Ghost_RUS"
# 120441  733530                    Sacada
# 120442  610660  Laush Dmitriy Sergeevich
# 120443  658870             xropi,stev3ns
# 120444  681550                       NaN
#
# [120445 rows x 13 columns]

# %% [markdown]
# DUPLICADOS Y NULOS

# %%
#Observar nulos
df_games.isnull().sum()
# Out:
# publisher       96362
# genres          91593
# app_name        88312
# title           90360
# url             88310
# release_date    90377
# tags            88473
# reviews_url     88312
# specs           88980
# price           89687
# early_access    88310
# id              88312
# developer       91609
# dtype: int64

# %%
#Eliminar columnas irrelevantes
columnas_a_eliminar = ['publisher', 'url', 'tags','specs','early_access','reviews_url','title']
df_games = df_games.drop(columnas_a_eliminar,axis=1)

# %%
# Eliminar registros con todas las columnas nulas
df_games.dropna(how='all', inplace=True)
df_games.isnull().sum()
# Out:
# genres          3283
# app_name           2
# release_date    2067
# price           1377
# id                 2
# developer       3299
# dtype: int64

# %%
#Analizar nulos de la columna 'id'
df_games[df_games['id'].isnull()]
# Out:
#                      genres                                        app_name  \
# 88384                   NaN                                             NaN
# 119271  [Action, Adventure]  Batman: Arkham City - Game of the Year Edition
#
#        release_date  price   id                                   developer
# 88384           NaN  19.99  NaN                                         NaN
# 119271   2012-09-07  19.99  NaN  Rocksteady Studios,Feral Interactive (Mac)

# %%
#Analizo el registro 119271
df_games[df_games["app_name"] == "Batman: Arkham City - Game of the Year Edition"]
# Out:
#                      genres                                        app_name  \
# 89378   [Action, Adventure]  Batman: Arkham City - Game of the Year Edition
# 119271  [Action, Adventure]  Batman: Arkham City - Game of the Year Edition
#
#        release_date  price      id                                   developer
# 89378    2012-09-07  19.99  200260  Rocksteady Studios,Feral Interactive (Mac)
# 119271   2012-09-07  19.99     NaN  Rocksteady Studios,Feral Interactive (Mac)

# %%
#Elimino registro 119271 por duplicado y eli,ino el registro 88384 por contener todos datos nulos salvo price
df_games.drop([119271,88384],inplace= True)

# %%
#Busco y analizo los duplicados
columnas_para_verificar = ['id']
duplicados_columnas = df_games[df_games.duplicated(subset=columnas_para_verificar)]
duplicados_columnas
# Out:
#           genres                          app_name release_date  price  \
# 102883  [Action]  Wolfenstein II: The New Colossus   2017-10-26  59.99
#
#             id      developer
# 102883  612880  Machine Games

# %%
#Analizo el registro 102883
df_games[df_games["app_name"] == "Wolfenstein II: The New Colossus"]
# Out:
#           genres                          app_name release_date  price  \
# 102204  [Action]  Wolfenstein II: The New Colossus   2017-10-26  59.99
# 102883  [Action]  Wolfenstein II: The New Colossus   2017-10-26  59.99
#
#             id      developer
# 102204  612880  Machine Games
# 102883  612880  Machine Games

# %%
#Elimino registro 102883 por duplicado
df_games.drop(102883,inplace= True)

# %%
#Vuelvo a revisar nulos
df_games.isnull().sum()
# Out:
# genres          3282
# app_name           1
# release_date    2066
# price           1377
# id                 0
# developer       3298
# dtype: int64

# %%
#Analizo nulo de app_game
df_games[df_games['app_name'].isnull()]
# Out:
#                 genres app_name release_date price      id developer
# 90890  [Action, Indie]      NaN   2014-08-26   NaN  317160       NaN

# %%
#Elimino registro 90890 por no contener ningún dato útil
df_games.drop(90890,inplace= True)

# %%
#Vuelvo a revisar nulos
df_games.isnull().sum()
# Out:
# genres          3282
# app_name           0
# release_date    2066
# price           1376
# id                 0
# developer       3297
# dtype: int64

# %%
#Reemplazo nulos reemplazados por "Sin Datos"
df_games = df_games.fillna("Sin Datos")
df_games
# Out:
#                                                    genres  \
# 88310       [Action, Casual, Indie, Simulation, Strategy]
# 88311                [Free to Play, Indie, RPG, Strategy]
# 88312   [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                         [Action, Adventure, Casual]
# 88314                                           Sin Datos
# ...                                                   ...
# 120440              [Casual, Indie, Simulation, Strategy]
# 120441                          [Casual, Indie, Strategy]
# 120442                        [Indie, Racing, Simulation]
# 120443                                    [Casual, Indie]
# 120444                                          Sin Datos
#
#                         app_name release_date         price      id  \
# 88310        Lost Summoner Kitty   2018-01-04          4.99  761140
# 88311                  Ironbound   2018-01-04  Free To Play  643980
# 88312    Real Pool 3D - Poolians   2017-07-24  Free to Play  670290
# 88313                    弹炸人2222   2017-12-07          0.99  767400
# 88314              Log Challenge    Sin Datos          2.99  773570
# ...                          ...          ...           ...     ...
# 120440            Colony On Mars   2018-01-04          1.99  773640
# 120441  LOGistICAL: South Africa   2018-01-04          4.99  733530
# 120442             Russian Roads   2018-01-04          1.99  610660
# 120443       EXIT 2 - Directions   2017-09-02          4.99  658870
# 120444               Maze Run VR    Sin Datos          4.99  681550
#
#                        developer
# 88310                  Kotoshiro
# 88311           Secret Level SRL
# 88312               Poolians.com
# 88313                       彼岸领域
# 88314                  Sin Datos
# ...                          ...
# 120440        Nikita "Ghost_RUS"
# 120441                    Sacada
# 120442  Laush Dmitriy Sergeevich
# 120443             xropi,stev3ns
# 120444                 Sin Datos
#
# [32131 rows x 6 columns]

# %% [markdown]
# TRANSFORMACIÓN DE LOS DATOS

# %%
#Observo tipo de dato
df_games.dtypes
# Out:
# genres          object
# app_name        object
# release_date    object
# price           object
# id              object
# developer       object
# dtype: object

# %%
#Convierto las columnas "id" a tipo int
df_games["id"] = df_games["id"].astype("Int64")

# %%
#Es necesario transformar la columna "date_release" para poder extraer el año. 
# Extraer el año de la columna "release_date" y reemplazar los valores nulos con "sin dato"
df_games['Año_estreno'] = df_games['release_date'].str.extract(r'(\d{4})').fillna('Sin Datos')
# Elimino la columna release_date
df_games.drop(columns=['release_date'], inplace=True)
df_games
# Out:
#                                                    genres  \
# 88310       [Action, Casual, Indie, Simulation, Strategy]
# 88311                [Free to Play, Indie, RPG, Strategy]
# 88312   [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                         [Action, Adventure, Casual]
# 88314                                           Sin Datos
# ...                                                   ...
# 120440              [Casual, Indie, Simulation, Strategy]
# 120441                          [Casual, Indie, Strategy]
# 120442                        [Indie, Racing, Simulation]
# 120443                                    [Casual, Indie]
# 120444                                          Sin Datos
#
#                         app_name         price      id  \
# 88310        Lost Summoner Kitty          4.99  761140
# 88311                  Ironbound  Free To Play  643980
# 88312    Real Pool 3D - Poolians  Free to Play  670290
# 88313                    弹炸人2222          0.99  767400
# 88314              Log Challenge          2.99  773570
# ...                          ...           ...     ...
# 120440            Colony On Mars          1.99  773640
# 120441  LOGistICAL: South Africa          4.99  733530
# 120442             Russian Roads          1.99  610660
# 120443       EXIT 2 - Directions          4.99  658870
# 120444               Maze Run VR          4.99  681550
#
#                        developer Año_estreno
# 88310                  Kotoshiro        2018
# 88311           Secret Level SRL        2018
# 88312               Poolians.com        2017
# 88313                       彼岸领域        2017
# 88314                  Sin Datos   Sin Datos
# ...                          ...         ...
# 120440        Nikita "Ghost_RUS"        2018
# 120441                    Sacada        2018
# 120442  Laush Dmitriy Sergeevich        2018
# 120443             xropi,stev3ns        2017
# 120444                 Sin Datos   Sin Datos
#
# [32131 rows x 6 columns]

# %%
#Columna price: 
#observo la composición de la columna
df_games["price"].unique()
# Out:
# array([4.99, 'Free To Play', 'Free to Play', 0.99, 2.99, 3.99, 9.99,
#        18.99, 29.99, 'Sin Datos', 'Free', 10.99, 1.59, 14.99, 1.99, 59.99,
#        8.99, 6.99, 7.99, 39.99, 19.99, 7.49, 12.99, 5.99, 2.49, 15.99,
#        1.25, 24.99, 17.99, 61.99, 3.49, 11.99, 13.99, 'Free Demo',
#        'Play for Free!', 34.99, 74.76, 1.49, 32.99, 99.99, 14.95, 69.99,
#        16.99, 79.99, 49.99, 5.0, 44.99, 13.98, 29.96, 119.99, 109.99,
#        149.99, 771.71, 'Install Now', 21.99, 89.99,
#        'Play WARMACHINE: Tactics Demo', 0.98, 139.92, 4.29, 64.99,
#        'Free Mod', 54.99, 74.99, 'Install Theme', 0.89, 'Third-party',
#        0.5, 'Play Now', 299.99, 1.29, 3.0, 15.0, 5.49, 23.99, 49.0, 20.99,
#        10.93, 1.39, 'Free HITMAN™ Holiday Pack', 36.99, 4.49, 2.0, 4.0,
#        9.0, 234.99, 1.95, 1.5, 199.0, 189.0, 6.66, 27.99, 10.49, 129.99,
#        179.0, 26.99, 399.99, 31.99, 399.0, 20.0, 40.0, 3.33, 199.99,
#        22.99, 320.0, 38.85, 71.7, 59.95, 995.0, 27.49, 3.39, 6.0, 19.95,
#        499.99, 16.06, 4.68, 131.4, 44.98, 202.76, 1.0, 2.3, 0.95, 172.24,
#        249.99, 2.97, 10.96, 10.0, 30.0, 2.66, 6.48, 19.29, 11.15, 18.9,
#        2.89, 'Play the Demo', 99.0, 87.94, 599.0, 8.98, 9.69, 0.49, 9.98,
#        9.95, 7.0, 'Starting at $499.00', 'Starting at $449.00', 12.89,
#        6.49, 1.87, 42.99, 41.99, 289.99, 'Free to Try', 23.96, 5.65, 12.0,
#        13.37, 189.96, 124.99, 'Free Movie', 19.98, 160.91, 'Free to Use'],
#       dtype=object)

# %%
#Observo dos registros problematicos
df_games[(df_games["price"] == 'Starting at $499.00') | (df_games["price"] == 'Starting at $449.00')]
# Out:
#            genres                 app_name                price      id  \
# 113310  Sin Datos      Syber Steam Machine  Starting at $499.00  353420
# 113311  Sin Datos  Alienware Steam Machine  Starting at $449.00  353390
#
#         developer Año_estreno
# 113310  Sin Datos        2015
# 113311  Sin Datos        2015

# %%
#Los modifico asumiendo price como el precio inicial
df_games.loc[df_games["price"] == 'Starting at $499.00', "price"] = '499.00'
df_games.loc[df_games["price"] == 'Starting at $449.00', "price"] = '449.00'

# %%
#Columna price: 
#Interpreto que el resto de los valores strings que el juego es gratis
#Defino función para poder reemplazar los datos string de la columna "price" por flotantes 0.0

def cambio_a_float(valor):

    if pd.isna(valor): #esta parte de la función es para el caso de que no exista ningun string o float en el campo
        return 0.0
    try:
        flotante = float(valor) #si el valor es float lo conservo
        return flotante
    except (ValueError, TypeError): #si el valor es diferente retorno 0.0
        return 0.0
    
#Aplico esta función a la columna precio
df_games["price"] = df_games["price"].apply(cambio_a_float)

# %%
df_games.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88314                                          Sin Datos
#
#                       app_name  price      id         developer Año_estreno
# 88310      Lost Summoner Kitty   4.99  761140         Kotoshiro        2018
# 88311                Ironbound   0.00  643980  Secret Level SRL        2018
# 88312  Real Pool 3D - Poolians   0.00  670290      Poolians.com        2017
# 88313                  弹炸人2222   0.99  767400              彼岸领域        2017
# 88314            Log Challenge   2.99  773570         Sin Datos   Sin Datos

# %% [markdown]
# VALORES ATIPICOS

# %%
print(df_games["price"].describe())
# Out:
# count    32131.000000
# mean         8.514355
# std         16.086231
# min          0.000000
# 25%          1.990000
# 50%          4.990000
# 75%          9.990000
# max        995.000000
# Name: price, dtype: float64

# %%
#Analizo boxplot

plt.figure(figsize=(10,12))
plt.boxplot(df_games["price"].dropna())
plt.show()

# %%
#Observo los juegos mas caros par evaluar si son valores atípicos o no
df_games[df_games["price"] > 200]
# Out:
#                                                    genres  \
# 90702                                        [Simulation]
# 92755   [Animation &amp; Modeling, Design &amp; Illust...
# 95172                                           Sin Datos
# 97384   [Animation &amp; Modeling, Design &amp; Illust...
# 97385   [Animation &amp; Modeling, Design &amp; Illust...
# 97727                                  [Video Production]
# 100045  [Animation &amp; Modeling, Design &amp; Illust...
# 100398  [Animation &amp; Modeling, Design &amp; Illust...
# 102065                                 [Video Production]
# 102614  [Animation &amp; Modeling, Design &amp; Illust...
# 103704                                       [Simulation]
# 104156               [Audio Production, Video Production]
# 105948       [Animation &amp; Modeling, Video Production]
# 106103         [Free to Play, Massively Multiplayer, RPG]
# 106104         [Free to Play, Massively Multiplayer, RPG]
# 111904                                          Sin Datos
# 113310                                          Sin Datos
# 113311                                          Sin Datos
# 115162  [Animation &amp; Modeling, Design &amp; Illust...
# 117876  [Animation &amp; Modeling, Education, Utilitie...
#
#                                                  app_name   price      id  \
# 90702                          X-Plane 10 Global - 64 Bit  771.71  292180
# 92755                                       MODO indie 10  299.99  401090
# 95172                                    ChessBase 13 Pro  234.99  377350
# 97384                           GameMaker Studio 2 Mobile  399.99  585620
# 97385                              GameMaker Studio 2 UWP  399.99  585610
# 97727                    MAGIX Video Pro X8 Steam Edition  399.00  598860
# 100045                     Marvelous Designer 7 For Steam  320.00  707410
# 100398    Strata Spaces VR – Professional Edition Upgrade  995.00  719000
# 102065                   MAGIX Video Pro X9 Steam Edition  399.00  750840
# 102614  CUR3D Maker Edition - Permission for commercia...  499.99  691560
# 103704                                        Pinball FX3  202.76  442120
# 104156                    VEGAS Pro 15 Edit Steam Edition  399.00  689790
# 105948                          FaceRig Studio - Personal  299.99  571690
# 106103                              EVE Online: 7430 PLEX  249.99  629795
# 106104                             EVE Online: 15400 PLEX  499.99  629796
# 111904                                           HTC Vive  599.00  358040
# 113310                                Syber Steam Machine  499.00  353420
# 113311                            Alienware Steam Machine  449.00  353390
# 115162                  CopperCube - Professional Edition  289.99  366190
# 117876             Clickteam Fusion 2.5 Developer Upgrade  299.99  267810
#
#                          developer Año_estreno
# 90702             Laminar Research        2014
# 92755                  The Foundry        2015
# 95172                    Chessbase        2016
# 97384              YoYo Games Ltd.        2017
# 97385              YoYo Games Ltd.        2017
# 97727          MAGIX Software GmbH        2017
# 100045         CLO Virtual Fashion        2017
# 100398  Strata Mixed Reality, Inc.        2017
# 102065         MAGIX Software GmbH        2017
# 102614             RUHRSOURCE GmbH        2017
# 103704                 Zen Studios        2017
# 104156         MAGIX Software GmbH        2017
# 105948            Holotech Studios        2017
# 106103                         CCP        2017
# 106104                         CCP        2017
# 111904                   Sin Datos        2016
# 113310                   Sin Datos        2015
# 113311                   Sin Datos        2015
# 115162                Ambiera e.U.        2015
# 117876                   Clickteam        2014

# %% [markdown]
# Observando las principales metricas estadisticas y los boxplots se descarta la existencia de valores atipicos en las variables numericas. Asumo que los valores altos de algunos items son razonables en este caso de negocio.

# %% [markdown]
# COLUMNA GENRES

# %%
df_games["genres"]
# Out:
# 88310         [Action, Casual, Indie, Simulation, Strategy]
# 88311                  [Free to Play, Indie, RPG, Strategy]
# 88312     [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                           [Action, Adventure, Casual]
# 88314                                             Sin Datos
#                                 ...
# 120440                [Casual, Indie, Simulation, Strategy]
# 120441                            [Casual, Indie, Strategy]
# 120442                          [Indie, Racing, Simulation]
# 120443                                      [Casual, Indie]
# 120444                                            Sin Datos
# Name: genres, Length: 32131, dtype: object

# %%
df_games.shape
# Out:
# (32131, 6)

# %%
#con explode hago que la columna genres tome cada valor que tiene almacenado y lo devuelva en un campo nuevo pero conservando el mismo id
df_games = df_games.explode("genres")
df_games = df_games.dropna(subset=["genres"])
df_games
# Out:
#             genres             app_name  price      id  \
# 88310       Action  Lost Summoner Kitty   4.99  761140
# 88310       Casual  Lost Summoner Kitty   4.99  761140
# 88310        Indie  Lost Summoner Kitty   4.99  761140
# 88310   Simulation  Lost Summoner Kitty   4.99  761140
# 88310     Strategy  Lost Summoner Kitty   4.99  761140
# ...            ...                  ...    ...     ...
# 120442      Racing        Russian Roads   1.99  610660
# 120442  Simulation        Russian Roads   1.99  610660
# 120443      Casual  EXIT 2 - Directions   4.99  658870
# 120443       Indie  EXIT 2 - Directions   4.99  658870
# 120444   Sin Datos          Maze Run VR   4.99  681550
#
#                        developer Año_estreno
# 88310                  Kotoshiro        2018
# 88310                  Kotoshiro        2018
# 88310                  Kotoshiro        2018
# 88310                  Kotoshiro        2018
# 88310                  Kotoshiro        2018
# ...                          ...         ...
# 120442  Laush Dmitriy Sergeevich        2018
# 120442  Laush Dmitriy Sergeevich        2018
# 120443             xropi,stev3ns        2017
# 120443             xropi,stev3ns        2017
# 120444                 Sin Datos   Sin Datos
#
# [74831 rows x 6 columns]

# %%
#cambio el nombre de la columna id por item_id
df_games.rename(columns={'id': 'item_id'}, inplace=True)

# %%
#Guardado CSV Opcional

# df_games.to_csv('Data/steam_games.csv', index=False, encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\risis\OneDrive\Escritorio\DS_Projects\de 0\ETL_games.ipynb Cell 37 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/risis/OneDrive/Escritorio/DS_Projects/de%200/ETL_games.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> #Guardado CSV
# ----> <a href='vscode-notebook-cell:/c%3A/Users/risis/OneDrive/Escritorio/DS_Projects/de%200/ETL_games.ipynb#X51sZmlsZQ%3D%3D?line=2'>3</a> df_games.to_csv('Data/steam_games.csv', index=False, encoding="utf-8")
#
# File c:\Users\risis\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File c:\Users\risis\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\risis\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File c:\Users\risis\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:737, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     735 # Only for write methods
#     736 if "r" not in mode and is_path:
# --> 737     check_parent_directory(str(handle))
#     739 if compression:
#     740     if compression != "zstd":
#     741         # compression libraries do not like an explicit text-mode
#
# File c:\Users\risis\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:600, in check_parent_directory(path)
#     598 parent = Path(path).parent
#     599 if not parent.is_dir():
# --> 600     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'Data'

# %%
#Guardado PARQUET
df_games.to_parquet('Data/steam_games.parquet', engine='pyarrow')
